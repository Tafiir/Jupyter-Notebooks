# %%
from scipy.optimize import fsolve

F = lambda x: 3 * (sin(x)-x*cos(x))/x**3
x_ = linspace(0,20,1000)
figure()
plot(x_, F(x_))
axhline(0, color='k')
grid()
show()

# %%
p = fsolve(F, [4,7,11])
display(p)
# Out:
# array([  4.49340946,   7.72525184,  10.90412166])
