# %%
import scipy.optimize as o
from sqlalchemy import create_engine

db = create_engine("sqlite:///213.db")

data2 = pd.read_sql('dämpfung', db)
data2.iloc[:,1] = 2*pi*data2.iloc[:,1] / 60
display(data2)
dw = 5/60

figure()
errorbar(data2.iloc[:,0], data2.iloc[:,1], yerr=dw, fmt='bs')
grid()
# yscale('log')
# Out:
#    Zeit $[s]$  $\omega_F \ [s^{-1}]$
# 0           0              72.780230
# 1         120              67.544242
# 2         240              62.308254
# 3         360              57.595865
# 4         480              53.407075
# 5         600              49.218285
# 6         720              46.076692

# %%
ff_d = lambda t, d: data2.iloc[0,1]*exp(-d*t)
popt, pcov = o.curve_fit(ff_d, data2.iloc[:,0], data2.iloc[:,1], sigma=dw, p0=1e-4)
D = popt[0]
dD = sqrt(pcov[0][0])
tau = -1/D
t12 = log(1/2) * tau
display(Latex(r"$D = {0:.2n} \pm {1:.2n}$".format(D, dD)))
display(Latex(r"$\tau = {0}$".format(tau)))
display(Latex(r"$t_{{1/2}} = {0}$".format(t12)))

figure()
errorbar(data2.iloc[:,0], data2.iloc[:,1], yerr=dw, fmt='bs')
plot(arange(0,1000, 0.1), ff_d(arange(0,1000, 0.1), D), 'r-')
grid(which='both')
yscale('log')
# Out:
# $D = 0.00064 \pm 3.1e-06$
# $\tau = -1553.1525859135486$
# $t_{1/2} = 1076.5633359053645$

# %%
data3 = pd.read_sql('präzession', db)
data3.iloc[:,0] = 2 * pi * data3.iloc[:,0] / 60
display(data3)
# Out:
#    $\omega_F \ [s^{-1}]$   $T_1$  $T_2$  $T_3$  $T_4$
# 0              70.685835  110.37  87.37  60.28  46.77
# 1              62.308254   97.64  74.75  52.58  40.73
# 2              44.505896   68.29  54.58  37.50  28.70
# 3              31.415927   50.12  38.59  26.64  20.62

# %%
exp_D = lambda t, w0: w0 * exp(-D*t)

w_end_cols = ['$\omega_F$',*['$\omega_{{end,{0}}} $'.format(i) for i in range(1,5)]]
w_end = pd.DataFrame([data3.iloc[:,0], *[exp_D(data3[i], data3.iloc[:,0]) for i in data3.iloc[:,1:]]], index=w_end_cols).transpose()
display(w_end)

wm_cols = ['$\omega_F$',*['$\\overline{{\omega_{{F,{0}}}}} $'.format(i) for i in range(1,5)]]
wm = pd.DataFrame([data3.iloc[:,0], *[(data3.iloc[:,0]+w_end[i])/2 for i in w_end.iloc[:,1:]]], index=wm_cols).transpose()
display(wm)
# Out:
#    $\omega_F$  $\omega_{end,1} $  $\omega_{end,2} $  $\omega_{end,3} $  \
# 0   70.685835          65.837085          66.819294          67.994975
# 1   62.308254          58.511787          59.380506          60.234193
# 2   44.505896          42.591429          42.969057          43.444195
# 3   31.415927          30.418322          30.644976          30.881669
#
#    $\omega_{end,4} $
# 0          68.589005
# 1          60.695516
# 2          43.691044
# 3          31.001598
#    $\omega_F$  $\overline{\omega_{F,1}} $  $\overline{\omega_{F,2}} $  \
# 0   70.685835                   68.261460                   68.752564
# 1   62.308254                   60.410021                   60.844380
# 2   44.505896                   43.548662                   43.737476
# 3   31.415927                   30.917124                   31.030451
#
#    $\overline{\omega_{F,3}} $  $\overline{\omega_{F,4}} $
# 0                   69.340405                   69.637420
# 1                   61.271224                   61.501885
# 2                   43.975045                   44.098470
# 3                   31.148798                   31.208762

# %%
ff_T = lambda w,m:m*w
popt = []
pcov = []
for i in range(0,4):
    figure()
    popt_, pcov_ = o.curve_fit(ff_T, wm.iloc[:,i+1], data3.iloc[:,i+1], sigma=0.5)
    popt.append(*popt_)
    pcov.append(pcov_)
    errorbar(wm.iloc[:,i+1], data3.iloc[:,i+1], yerr=0.5, fmt='s')
    plot(arange(30,70,0.1), ff_T(arange(30,70,0.1), popt_))
    xlabel(r"$\overline{\omega_F}$")
    ylabel(r"$T_P$")
    title(r"$T_P$ als Funktion von $\overline{{\omega_F}}$ (Masse {0})".format(i+1))
    grid()
    show()
    display(Latex(r"$s_{0} = {1:.5} \pm {2:.2} $".format(i+1, *popt_, sqrt(pcov_[0][0]))))
# Out:
# $s_1 = 1.6088 \pm 0.011 $
# $s_2 = 1.2508 \pm 0.011 $
# $s_3 = 0.86169 \pm 0.0039 $
# $s_4 = 0.66413 \pm 0.0043 $

# %%
from fehler import fehler
m = 9.85e-3
g = 9.80984
s_s, m_s, l_s = sm.symbols('s m l')
ds_s, dm_s, dl_s = sm.symbols('ds dm dl')
Iz = s_s/(2*pi) * m_s * g * l_s
Iz_abs, Iz_rel = fehler(Iz, s_s, m_s, l_s)
dataI = pd.DataFrame([pd.Series([Iz.subs([(s_s,popt[0]),
                                          (m_s,m),
                                          (l_s, 0.15)
                                         ]),
                                 Iz.subs([(s_s,popt[1]),
                                          (m_s,m),
                                          (l_s, 0.2)
                                         ]),
                                 Iz.subs([(s_s,popt[2]),
                                          (m_s,2*m),
                                          (l_s, 0.15)
                                         ]),
                                 Iz.subs([(s_s,popt[3]),
                                          (m_s,2*m),
                                          (l_s, 0.20)
                                         ])
                                ], name="$I_z$"),
                      pd.Series([Iz_abs.subs([(s_s,popt[0]),
                                              (m_s,m),
                                              (l_s, 0.15),
                                              (ds_s, sqrt(pcov[0][0][0])),
                                              (dm_s, 0),
                                              (dl_s, 0.005)
                                             ]),
                                 Iz_abs.subs([(s_s,popt[1]),
                                              (m_s,2*m),
                                              (l_s, 0.15),
                                              (ds_s, sqrt(pcov[1][0][0])),
                                              (dm_s, 0),
                                              (dl_s, 0.005)
                                             ]),
                                 Iz_abs.subs([(s_s,popt[2]),
                                              (m_s,m),
                                              (l_s, 0.20),
                                              (ds_s, sqrt(pcov[2][0][0])),
                                              (dm_s, 0),
                                              (dl_s, 0.005)
                                             ]),
                                 Iz_abs.subs([(s_s,popt[3]),
                                              (m_s,2*m),
                                              (l_s, 0.20),
                                              (ds_s, sqrt(pcov[3][0][0])),
                                              (dm_s, 0),
                                              (dl_s, 0.005)
                                             ])
                     ], name="$\Delta I_z$")], dtype=float).transpose().round(5)
display(dataI)
I_z = dataI.iloc[:,0].mean()
dI_z = 1/4*sqrt(sum(dataI.iloc[:,1]**2))
display(Latex(r"$I_z = {0:.5f} \pm {1:.5f} $".format(I_z,dI_z)))
# Out:
#      $I_z$  $\Delta I_z$
# 0  0.00371       0.00013
# 1  0.00385       0.00020
# 2  0.00398       0.00007
# 3  0.00409       0.00011
# $I_z = 0.00391 \pm 0.00007 $

# %%
data4 = pd.read_sql('drehachse', db)
data4.iloc[:,0] = 2 * pi * data4.iloc[:,0]/60
data4["$\Omega $"] = 2*pi*10/data4.iloc[:,1]
data4["$\Delta \Omega $"] = 2*pi*10/(data4.iloc[:,1]**2)*0.2
display(data4)
# Out:
#    $\omega_F$  $T_{{10}}$  $\Omega $  $\Delta \Omega $
# 0   60.213859       16.54   3.798782          0.045934
# 1   57.595865       17.70   3.549822          0.040111
# 2   54.977871       18.65   3.369000          0.036129
# 3   52.359878       19.26   3.262298          0.033876
# 4   49.741884       20.51   3.063474          0.029873
# 5   47.123890       21.59   2.910229          0.026959
# 6   44.505896       22.81   2.754575          0.024152
# 7   41.887902       24.51   2.563519          0.020918
# 8   39.269908       25.90   2.425940          0.018733
# 9   36.651914       27.65   2.272400          0.016437

# %%
ff_O = lambda w, p: p*w
popt, pcov = o.curve_fit(ff_O, data4.iloc[:,0], data4.iloc[:,2], sigma=data4.iloc[:,3])
p = popt[0]

figure()
errorbar(data4.iloc[:,0], data4.iloc[:,2], yerr=data4.iloc[:,3], fmt='bs')
plot(arange(35,65,0.1), ff_O(arange(35,65,0.1), p), 'r-')
xlabel(r"$\omega_F$")
ylabel(r"$\Omega$")
grid()
show()

display(Latex(r"Steigung: ${0}$".format(p)))
Iz_s, p_s, dIz_s, dp_s = sm.symbols('I_z p dI_z dp')
Ix = Iz_s*(1/(1-p_s))
Ix_abs, Ix_rel = fehler(Ix, Iz_s, p_s)
I_x = float(Ix.subs([(Iz_s, I_z), (p_s, p)]))
dI_x = float(Ix_abs.subs([(Iz_s, I_z), (p_s, p), (dIz_s, dI_z), (dp_s, sqrt(pcov[0][0]))]))
display(Latex(r"$I_x = {0:.5f} \pm {1:.5f} $".format(I_x, dI_x)))
display(Latex(r"$I_x = {0}$".format(sm.latex(Ix))))
# Out:
# Steigung: $0.061798150406901516$
# $I_x = 0.00416 \pm 0.00007 $
# $I_x = \frac{I_{z}}{- p + 1}$

# %%
data5 = 2* pi * pd.read_sql('nutation', db)/60

dw_N = 10/60

display(data5)
# Out:
#    $\omega_F$  $\omega_N$
# 0   81.157810   75.398224
# 1   73.303829   68.591440
# 2   68.067841   63.879051
# 3   65.449847   61.261057
# 4   62.831853   59.166662
# 5   57.072267   53.930674
# 6   52.359878   48.694686
# 7   49.741884   46.076692
# 8   48.171087   43.458698
# 9   40.317106   36.651914

# %%
ff_N = lambda w, p: p*w
popt_N, pcov_N = o.curve_fit(ff_N, data5.iloc[:,0], data5.iloc[:,1], sigma=dw_N)
p_N = popt_N[0]

figure()
errorbar(data5.iloc[:,0], data5.iloc[:,1], yerr=dw_N, fmt='bs')
plot(arange(40,85,0.1), ff_N(arange(40,85,0.1), p_N), 'r-')
xlabel(r"$\omega_F$")
ylabel(r"$\omega_N$")
grid()
show()

display(Latex(r"Steigung: ${0}$".format(p_N)))
I_xN = I_z/p_N
dI_xN = I_xN * sqrt((dI_z/I_z)**2 + (sqrt(pcov_N[0][0])/p_N)**2)
display(Latex(r"$I_x = {0:.5f} \pm {1:.5f}$".format(I_xN, dI_xN)))
# Out:
# Steigung: $0.9320495550264267$
# $I_x = 0.00419 \pm 0.00007$
