# %% [markdown]
# ## Aufgabe 1

# %%
I = 5*1.1
dI = 0.1
U = 5.44
dU = 0.08
f = 328/60
df = 1/60
valerr("P" , U*I, sqrt((dU*I)**2 + (dI*U)**2).round(2))
display(Latex(r"$W = ({0:.2f} \pm {1:.2f}) J$".format(U*I/f, U*I/f*sqrt((dU/U)**2 + (dI/I)**2 + (df/f)**2))))
# Out:
# $P = 29.92 \pm 0.7 \ $
# $W = (5.47 \pm 0.13) J$

# %%
I = array([2.4,2.25]).mean()
dI = sqrt(sum(array([0.06, 0.05])**2))
U = 24
dU = 0.4
f = 328/60
df = 1/60
display(Latex(r"$P = ({0:.2f} \pm {1:.2f}) \frac{{J}}{{s}}$".format(U*I, sqrt((dU*I)**2 + (dI*U)**2))))
display(Latex(r"$W = ({0:.2f} \pm {1:.2f}) J$".format(U*I/f, U*I/f*sqrt((dU/U)**2 + (dI/I)**2 + (df/f)**2))))
# Out:
# $P = (55.80 \pm 2.09) \frac{J}{s}$
# $W = (10.21 \pm 0.38) J$

# %% [markdown]
# ## Aufgabe 2

# %%
t = 200
dt = 5
lh2o = 335
display(Latex(r"$W = {0:.0f} J$".format(335)))
display(Latex(r"$P = ({0:.3f} \pm {1:.3f}) \frac{{J}}{{s}}$".format(335/t, 335/t * dt/t)))
# Out:
# $W = 335 J$
# $P = (1.675 \pm 0.042) \frac{J}{s}$

# %% [markdown]
# ## Aufgabe 3

# %%
f_ = array([330,323,327])/60
df = float64(1/60)

f = f_.mean()

valerr("f", f.round(3), df.round(3), "s^{{-1}}")

I = 2.53 * 5
dI = 0.17 * 5

U = 11.5
dU = 1.1

Q_el = U*I/f
dQ_el = U*I/f*sqrt((dU/U)**2 + (dI/I)**2 + (df/f)**2)

valerr("P_{{el}}", float64(U*I).round(0), sqrt((dU*I)**2 + (dI*U)**2).round(0), "W")
valerr("Q_{{el}}", (U*I/f).round(1), (U*I/f*sqrt((dU/U)**2 + (dI/I)**2 + (df/f)**2)).round(1), "J")

T_ab = 22.5
dT = 0.1
T_zu = 17.2

cw = 4200
p = 998.2

V = 257e-6/60
dV = 2e-6/60

P_ab = float64(cw * p * (T_ab - T_zu) * V)
dP_ab = P_ab * sqrt((dV/V)**2 + 2*(dT/(T_ab-T_zu))**2)

Q_ab = P_ab/f
dQ_ab = Q_ab * sqrt((dP_ab/P_ab)**2 + (df/f)**2)

valerr("P_{{ab}}", P_ab.round(1), dP_ab.round(1), "W")
valerr("Q_{{ab}}", Q_ab.round(2), dQ_ab.round(2), "J")

A_ = array([19857, 20328, 20014]) * 10**(-4)
Q_pv = A_.mean()
dQ_pv = A_.std()
P_pv = Q_pv*f
dP_pv = sqrt((df*Q_pv)**2 + (f*dQ_pv)**2)

valerr("P_{{pV}}", P_pv.round(2), dP_pv.round(2), "W")
valerr("Q_{{pV}}", Q_pv.round(3), dQ_pv.round(3), "J")

n_th = Q_pv/Q_el
dn_th = n_th * sqrt((dQ_pv/Q_pv)**2 + (dQ_el/Q_el)**2)

valerr("\eta_{{th}}", n_th.round(4), dn_th.round(4))

valerr("Q_V",(Q_el - Q_ab - Q_pv).round(1), sqrt(dQ_el**2 + dQ_ab**2 + dQ_pv**2).round(1), "J")
# Out:
# $f = 5.444 \pm 0.017 \ s^{{-1}}$
# $P_{{el}} = 145.0 \pm 17.0 \ W$
# $Q_{{el}} = 26.7 \pm 3.1 \ J$
# $P_{{ab}} = 95.2 \pm 2.6 \ W$
# $Q_{{ab}} = 17.48 \pm 0.49 \ J$
# $P_{{pV}} = 10.93 \pm 0.11 \ W$
# $Q_{{pV}} = 2.007 \pm 0.02 \ J$
# $\eta_{{th}} = 0.0751 \pm 0.0088$
# $Q_V = 7.2 \pm 3.2 \ J$

# %%
l = 0.25

F = array([0.8, 0.6, 0.4, 0.2])
dF = array([0.1, 0.05, 0.05, 0.1])

D = l * F
dD = l * dF

W_D = D * 2*pi
dW_D = dD * 2*pi

A = array([[21884, 23322, 24976],
           [24471, 24636, 24119],
           [23499, 23575, 23512],
           [22450, 21824, 21965]]) * 10**(-4)
W_pv = A.mean(axis=1)
dW_pv = A.std(axis=1)

U = array([11.47, 11.48, 11.44, 11.48])
dU = 1.1

I = array([2.53, 2.54, 2.55, 2.54]) * 5
dI = 0.17 * 5

f_ = array([[205, 216, 211],
           [249, 241, 243],
           [282, 280, 281],
           [315, 314, 316]])/60
f = f_.mean(axis=1)
df = float64(1/60)

Q_el = U * I / f
dQ_el = Q_el * sqrt((dU/U)**2 + (dI/I)**2 + (df/f)**2)

for i in range(4):
    display(Latex("Messung {0}".format(i+1)))
    valerr("W_D", W_D[i], dW_D[i], "J")
    valerr("W_{{pV}}", W_pv[i], dW_pv[i], "J")
    valerr("Q_{{el}}", Q_el[i], dQ_el[i], "J")
# Out:
# Messung 1
# $W_D = 1.2566370614359172 \pm 0.15707963267948966 \ J$
# $W_{{pV}} = 2.3394 \pm 0.1263329991200505 \ J$
# $Q_{{el}} = 41.324667721518985 \pm 4.843064884809062 \ J$
# Messung 2
# $W_D = 0.9424777960769379 \pm 0.07853981633974483 \ J$
# $W_{{pV}} = 2.440866666666667 \pm 0.021561745961050725 \ J$
# $Q_{{el}} = 35.8025648021828 \pm 4.187140963840758 \ J$
# Messung 3
# $W_D = 0.6283185307179586 \pm 0.07853981633974483 \ J$
# $W_{{pV}} = 2.352866666666667 \pm 0.0033189690501049794 \ J$
# $Q_{{el}} = 31.14448398576512 \pm 3.6457237361112997 \ J$
# Messung 4
# $W_D = 0.3141592653589793 \pm 0.15707963267948966 \ J$
# $W_{{pV}} = 2.207966666666667 \pm 0.026811730434436607 \ J$
# $Q_{{el}} = 27.770666666666664 \pm 3.24701119282645 \ J$

# %%
n_th = W_pv/Q_el
dn_th = n_th * sqrt((dW_pv/W_pv)**2 + (dQ_el/Q_el)**2)

n_eff = W_D/Q_el
dn_eff = n_eff * sqrt((dW_D/W_D)**2 + (dQ_el/Q_el)**2)

figure()
errorbar(f, n_th, yerr=dn_th, fmt='bs')
xlabel(r"$f \ [s^{{-1}}] $")
ylabel(r"$\eta_{{th}}$")
grid()
show()

figure()
errorbar(f, n_eff, yerr=dn_eff, fmt='bs')
xlabel(r"$f \ [s^{{-1}}] $")
ylabel(r"$\eta_{{eff}}$")
grid()
minorticks_on()
show()
