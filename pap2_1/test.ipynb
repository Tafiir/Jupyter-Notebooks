# %%
import scipy.optimize as o

data2 = pd.read_csv('213_dämpfung.csv')
data2["Frequenz"] = data2["Frequenz"] / 60
display(data2)
dw = 5/10

fig = figure()
errorbar(data2["Zeit"], data2["Frequenz"], yerr=dw, fmt='bs')
grid()
# Out:
#    Zeit   Frequenz
# 0     0  11.583333
# 1   120  10.750000
# 2   240   9.916667
# 3   360   9.166667
# 4   480   8.500000
# 5   600   7.833333
# 6   720   7.333333
